# %% [markdown]
# ![Logo.png](attachment:c9188f9f-cd30-4e98-bacc-726ee45a48e9.png)

# %% [markdown]
# # SOFT40161 - Introduction to Computer Programming
# # Submission of the Coursework
#
# ## Name: Nikhil Verma
# ## NTU ID: N1217583

# %% [markdown]
# <font  color= 'red'> **The Full description of the Coursework is here -** </font>

# %% [markdown]
# <a href="https://now.ntu.ac.uk/d2l/le/content/1037562/viewContent/13280440/View">SOFT40161-Coursework (Click here)</a>

# %% [markdown]
# # Start your answer here-

# %% [markdown]
# <font  color= 'green'> **GitHub Link to access your activity.** </font>

# %% [markdown]
# Please add your Link here: <a href="https://github.com/Nikhil5566/N1217583">Github repository Link </a>

# %% [markdown]
# # ABOUT THE DATASET
#
# - This dataset is about the NVIDIA stock market from the year 1999 - 2024.
# - NVIDIA is one of the biggest corperation which produces graphics cards and chipset for home computers and console games, nvidia has made such a impact on gaming industry like no other.
# they were the first to make games graphically better for pc gamers and console gamers by making a seperate chip for games that renders the games seperate from the cpu as the games will render on the ndidia chip that that will reduce the rendering load from the cpu and also enhance the performance as now cpu and nvidia chip is working seperatly to make the games perform better to produde better graphics.
# - NVIDIA is located in Santa clara, California, USA. NVIDIA follows fabless business model, where they do not own the manufacturing facility they work on a model where they design and develop and the production is handeled by other manufacturing companies.
# - The company was founded by Curtis Priem, Chris Malachowsky and jen-Hsun Huang in 1993, where these three friends were sitting in a cafe where they planned and decided to make a gaming chipset companies where they will help make gaming industry to go next level in performance. where in the year 1995 they lauched there GPU NV1-(STG-2000) after that this company never looked back and also reaching market capitalization of approximately 3.400+ Trillion dollars.
# - This dataset dives deep into the stock market with deeper understanding for the company as a whole and trying to study the insights of the companies where they win in which year what are their best and best decisions about the company, basiclly trying to find the important data related to the company and also study and understand with help of data visualization.

# %%
# importing necessary libraries

import pandas as pd, numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
# Connecting dataset to fetch data from the github where the dataset is uploaded

url = "https://raw.githubusercontent.com/Nikhil5566/N1217583/refs/heads/main/NVDA_1999-01-01_2024-12-04.csv"
NVDA_df= pd.read_csv(url)

# %% [markdown]
# # Section 1: Control Structures (16 marks)

# %% [markdown]
# # EXPLANATION:
#
# - Dataset Dimensions:
#  The shape attribute of the DataFrame, NVDA_df is utilized to fetch the number of rows and columns.
#  The values are printed through formatted strings.
#
# - Column Type Classification:
#  A list comprehension has been done for getting columns with a numeric data type, num_cols. where the data type is not equal to object.
#  In the same way, columns with object-type data obj_cols where the data type is equal to object.
#
# - Date-Based Filtering:
#  A prompt for the user to input a date in the `YYYY-MM-DD` format.
#  The pd.to_datetime function checks for the date format. If the input format is wrong, it raises a ValueError.
#  In case the date format is correct, then the DataFrame gets filtered into rows where the Date column equals the entered date.
#  In case no rows are present, it prints a message saying no data; else, the filtered rows will be shown.
#
# - Error Handling:
#  A try-except block has been given to handle the dates entered in the wrong format. The appropriate error message gets printed.
#
# # DOCUMENTATION:
#
# EDA on NVIDIA Dataset, NVDA_df, based on the following functionality:
#
# - Overview:
# Printing the count of the number of rows and columns in the dataset.
#
# - Categorize Columns:
# Using list comprehensions, it displays which all columns are numeric and which are object types.
#
# - Filtering based on Date:
# Prompting the user to input a date in the `YYYY-MM-DD` format.
# Validating the date format; if correct, filter the dataframe for the rows at that date.
# In case of finding, it displays the filtered data; otherwise, it displays an appropriate message.
#
# - Error Handling:
# Handles the case so that the program does not crash due to an invalid date format.

# %%
# Printing the number of rows and coloums: 
# This provides a quick overview of the dataset's size.

print(f"There are {NVDA_df.shape[0]} number of rows in the dataset")
print(f"There are {NVDA_df.shape[1]} number of columns in the dataset")
# Out:
# There are 6509 number of rows in the dataset
# There are 7 number of columns in the dataset

# %%
# Using control structure to make a list of columns that are not object
# This creates a list of columns whose data types are not 'object', typically numeric types.

num_cols = [x for x in NVDA_df.columns if NVDA_df[x].dtypes != object]

# %%
# Identifying object-type columns in the dataset
# This creates a list of columns with data type 'object', typically strings or categorical data.

obj_cols = [x for x in NVDA_df.columns if NVDA_df[x].dtypes == object]

# %%
try:
    # Prompting the user to input a date in the specified format
    select_date = input("Enter a date in YYYY-MM-DD format: ").strip()

    # Validate the input date format
    # This will check that the input is in proper 'YYYY-MM-DD' format and raise if it is an invalid entry
    pd.to_datetime(select_date, format='%Y-%m-%d')  # Raises ValueError if format is wrong

    # Filter the DataFrame (no need to convert NVDA_df.Date if it's in string format)
    # Assumes NVDA_df's 'Date' column contains date strings in proper format
    filtered_df = NVDA_df[NVDA_df['Date'] == select_date]

    # Check to see if there are any rows in now filtered DataFrame
    # If no rows were found inform user
    if filtered_df.empty:
        print("No data found for the entered date.")
    else:
        # Show rows that matched the date entered
        print(filtered_df)

except ValueError:
    # Handle bad entry and let the user know
    print("Invalid date format. Please enter the date in YYYY-MM-DD format.")
# Out:
# No data found for the entered date.

# %% [markdown]
# # REFLECTIONS:
# This code snippet is a good start for doing some basic exploratory data analysis on this dataset. Strengths and weaknesses of the approach are listed below:
#
# - Printing is done using formatted strings so that outputs are just a summary of information.
# - This helps automate the processes of classification into numeric and object columns and hence generalizes to various structured datasets.
# - It is the user's date filter input that makes the code interactive and flexible in applying the filter.
# - The try-except block prevents crashes. Additionally, the user experience is improved regarding clarity in feedback.

# %% [markdown]
# # Section 2: Functions and Modules (16 marks)

# %% [markdown]
# # EXPLANATION:
#
# Mean Volume Calculation:
# - The function meanVolume will calculate the average trading volume of the stocks.
# - This function will iterate over the Volume column, append values into the list, and calculate mean as a division of a sum of that list by the number of rows in the DataFrame.
# - The function prints a mean value formatted to two decimal places.
#
# Identifying the Trend:
# - This function trend_identify() will find out the trend in closing stock prices: Up, Down, Flat, based on the difference between consecutive days.
# - It uses the method diff for column difference and then applies a lambda function to classify the trend.
# - A new column with the name Trend will be added in the DataFrame.
#
# Correlation Heatmap:
# - To understand the correlation between the volume of stocks with any predefined parameter. By default, this is 'Close'.
# - The function will extract the Volume and the column specified into a new DataFrame, then calculates the correlations and plots a heatmap using Seaborn.
#
# # DOCUMENTATION:
#
# - meanVolume(df):
#    - It calculates and prints the mean of the 'Volume' column in the DataFrame.
#    - Parameters:
#       - df (DataFrame): The input dataset which has a 'Volume' column.
#
#
# - trend_identify(df, column="Close"):
#    - It identifies the trends in the mentioned column, based on day-to-day variations and categorizes it.
#    - Adds a new 'Trend' column in the DataFrame.
#    - Parameters:
#       - df (DataFrame): The input dataset
#       - column (str) The column which will be used for identifying the trend, by default "Close".
#
#
# - correlation_close(df, parm="Close"):
#    - A heatplot showing the correlation between 'Volume' and any mentioned column is plotted.
#    - Parameters:
#       - df (DataFrame): The input dataset
#       - parm (str) The column for which correlation between 'Volume' is to be plotted, by default "Close".

# %%
# Defining a function to calculate mean of Volume

l = []

def meanVolume(df):
    for x in df["Volume"]:
        l.append(x)
        
        mean = sum(l)/len(df)

    print(f"Mean of Volume is {mean:.2f}")

# %%
# Calling the meanVolume function

meanVolume(NVDA_df)
# Out:
# Mean of Volume is 601773903.98

# %%
# Defining a function to calculte the trend of the NVDA closing stock price

def trend_identify(df, column = "Close"):
    df["Trend"] = df[column].diff().apply(lambda x: "Up" if x>0 else "Down" if x<0 else "Flat")
    return df

# %%
trend_identify(NVDA_df)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1999-01-22    0.043750    0.048828    0.038802    0.041016    0.017325
# 1     1999-01-25    0.044271    0.045833    0.041016    0.045313    0.019140
# 2     1999-01-26    0.045833    0.046745    0.041146    0.041797    0.017655
# 3     1999-01-27    0.041927    0.042969    0.039583    0.041667    0.017600
# 4     1999-01-28    0.041667    0.041927    0.041276    0.041536    0.017544
# ...          ...         ...         ...         ...         ...         ...
# 6504  2024-11-26  137.699997  139.300003  135.669998  136.919998  136.919998
# 6505  2024-11-27  135.009995  137.220001  131.800003  135.339996  135.339996
# 6506  2024-11-29  136.779999  139.350006  136.050003  138.250000  138.250000
# 6507  2024-12-02  138.830002  140.449997  137.820007  138.630005  138.630005
# 6508  2024-12-03  138.259995  140.539993  137.949997  140.259995  140.259995
#
#           Volume Trend
# ...

# %%
# Making a function for plotting a correlation heatmap

def correlation_close(df, parm = "Close"):
    new_df = df[["Volume", parm]]
    sns.heatmap(new_df.corr(), annot = True, cmap = "Greens")

# %% [markdown]
# # REFLECTION:
#
# This code performs structured exploratory data analysis on stock data, from computation to visualization. Each function has been defined for a certain type of analysis, and that keeps the code modular, thus reusable.
#
# - Each function has an objective, like computing the average, analyzing the trend, or visualizing the correlation.
# - Functions here, such as trend_identify and correlation_close, are open to parameters; therefore, they may be easily extended to almost any dataset and analytical need.
# - Heatmap of the correlation gives intuitive feel toward variable-variable relationship and provides more readability to the analysis.
# - The sample code put the importance of thought process and breakdown of complex analytical tasks into smaller, manageable chunks. This also underlines the fact that a combination of statistical methods, trend analysis, and visualization amounts to the added value in deriving the insights which will support actionable intelligence from data. Equally, it underscores the importance of solid error handling, good practices in efficient programming, and unambiguous communication in function behavior. Building improvements from such areas, this really lays the groundwork for advanced data analysis workflows.
#
# This actually balances the requirement for functionality with clarity and strength of the code. While the code is effective at the core EDA tasks, further refinement in best practices for error handling, variable scoping, and documentation would enhance the quality. In addition, integrating more visualizations or statistical analyses would enrich the insight found within the dataset.

# %% [markdown]
# # Section 3: Data Handling with Pandas (16 marks)

# %% [markdown]
# # Explanation:
# - This code is a basic preprocessing of data along with exploratory data analysis, which is quite necessary to make sure that the dataset is clean and consistent for any analysis.
#
# - Checking DataFrame Information:
# NVDA_df.info() -Quick view of information concerning the DataFrame: count of non-null entries along with data types of columns, and memory used. It helps in understanding the data types and possible missing values.
#
# - Converting Date Column:
#     - NVDA_df["Date"] = pd.to_datetime(NVDA_df["Date"]) - The 'Date' column is converted from object/string type to datetime for easier manipulation and analysis of time-based data.
# Missing Value Check:
#
#     - NVDA_df.isna().sum() - Calculates total count of missing values in each column. This helps in identifying the incomplete data that might need imputation or removal.
# Descriptive Statistics:
#
#     - NVDA_df.describe() - Summary statistics are generated for numeric columns, including mean, std., min., and max values among others; thus, giving an idea about the distribution of data.
# - Dropping Unwanted Columns:
#     - NVDA_df.drop("Adj Close", axis=1, inplace=True) - This line removes the 'Adj Close' column from the DataFrame since the column is not needed for the analysis.
#
# - Filtering Numeric Columns:
# num_cols = [x for x in NVDA_df.columns if NVDA_df[x].dtypes!= object]: This creates a list of all numeric columns within the DataFrame by filtering out object-type columns.
# num_cols = [x for x in num_cols if x!= "TrendValue"]: Additional filtering of numeric columns to exclude the TrendValue column.
# - DataFrame Preview
# NVDA_df.head(): Shows the first five rows of the DataFrame enough to give an overview of its structure and modified content in there.
#
# # Documentation:
# - NVDA_df.info()
#     - Displays a summary of the DataFrame, including column names, data types, non-null counts, and memory usage. Useful for understanding the dataset's structure and identifying potential issues.
#
# - Converting the 'Date' column to datetime format - NVDA_df["Date"] = pd.to_datetime(NVDA_df["Date"])
#     - Converts the 'Date' column from object type to datetime format to enable time-based analysis.
#
# - Checking for missing values
#     - NVDA_df.isna().sum() - Calculates and displays the number of missing values in each column of the DataFrame.
#
# - Generating descriptive statistics
#     - NVDA_df.describe() - Provides summary statistics for numeric columns, including count, mean, standard deviation,
# minimum, and maximum values.
#
# - Dropping the 'Adj Close' column
#     - NVDA_df.drop("Adj Close", axis=1, inplace=True)
#     - Removes the 'Adj Close' column from the DataFrame as it is not relevant to the analysis.
#
# - Filtering numeric columns:
#     - num_cols = [x for x in NVDA_df.columns if NVDA_df[x].dtypes != object]
#     - num_cols = [x for x in num_cols if x != "TrendValue"]
#
# - Creates a list of numeric columns in the DataFrame, excluding object-type columns and the 'TrendValue' column.
#
# - Previewing the first five rows of the DataFrame
#     - NVDA_df.head() - Displays the first five rows of the DataFrame to verify the changes made during preprocessing.

# %%
# Checking for information of the dataframe

NVDA_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6509 entries, 0 to 6508
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       6509 non-null   object
#  1   Open       6509 non-null   float64
#  2   High       6509 non-null   float64
#  3   Low        6509 non-null   float64
#  4   Close      6509 non-null   float64
#  5   Adj Close  6509 non-null   float64
#  6   Volume     6509 non-null   int64
#  7   Trend      6509 non-null   object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 406.9+ KB

# %%
# As the Date column is wrongly typecasted as object let's convert it to datetime format

NVDA_df["Date"] = pd.to_datetime(NVDA_df["Date"])

# %%
# Checking dtypes of the columns in dataframe

NVDA_df.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# Trend                object
# dtype: object

# %%
# Checking for missing values in the dataframe

NVDA_df.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# Trend        0
# dtype: int64

# %%
# Checking for mean, max and so on of the dataframe

NVDA_df.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           6509  6509.000000  6509.000000  6509.000000
# mean   2011-12-28 18:02:55.879551488     7.846563     7.989922     7.689917
# min              1999-01-22 00:00:00     0.034896     0.035547     0.033333
# 25%              2005-07-13 00:00:00     0.279427     0.287250     0.272250
# 50%              2011-12-27 00:00:00     0.462750     0.469500     0.456250
# 75%              2018-06-15 00:00:00     4.450750     4.514500     4.378250
# max              2024-12-03 00:00:00   149.350006   152.889999   146.259995
# std                              NaN    21.342285    21.722479    20.897965
#
#              Close    Adj Close        Volume
# count  6509.000000  6509.000000  6.509000e+03
# mean      7.846531     7.679767  6.017739e+08
# min       0.034115     0.014410  1.968000e+07
# 25%       0.279250     0.117953  3.413160e+08
# 50%       0.463000     0.212784  5.033400e+08
# ...

# %%
# Dropping Adj Close column as for our project it seems of no use

NVDA_df.drop("Adj Close", axis= 1, inplace = True)

# %%
# Again making a list of columns that are not object

num_cols = [x for x in NVDA_df.columns if NVDA_df[x].dtypes != object]
num_cols = [x for x in num_cols if x != "TrendValue"]

# %%
# Checking for the first 5 rows of the dataframe after dropping the column

NVDA_df.head()
# Out:
#         Date      Open      High       Low     Close      Volume Trend
# 0 1999-01-22  0.043750  0.048828  0.038802  0.041016  2714688000  Flat
# 1 1999-01-25  0.044271  0.045833  0.041016  0.045313   510480000    Up
# 2 1999-01-26  0.045833  0.046745  0.041146  0.041797   343200000  Down
# 3 1999-01-27  0.041927  0.042969  0.039583  0.041667   244368000  Down
# 4 1999-01-28  0.041667  0.041927  0.041276  0.041536   227520000  Down

# %% [markdown]
# # Reflection:
#
# - Full Data Understanding
#     - NVDA_df.info() and NVDA_df.describe() give one a very good overview of the dataset structure and statistical properties. That is extremely useful for catching the issues which might pop up at the very beginning of the analysis.
#
# - Data Cleaning
#     - Casting the Date column to datetime allows compatibility with any kind of time-based operation that one may want to perform on the dataset. This is crucial for any kind of dataset where time is a factor.
#     - The NVDA_df.isna().sum() gives underlined data quality issues that could be problematic for further steps.
#
# - Focusing on the Relevant Data
#     - Dropping the Adj Close column- This demonstrates awareness of the context of the dataset. One is able to stream the data without keeping data that are superfluous.
#
# - Column Filtering
#     - The creation of num_cols allows for higher-order operations to be done on the appropriate data type, enhancing efficiency and reducing the possibilities of errors.
#
# - Observation on Changes
#     - The head() method, NVDA_df.head(), is applied to the modified DataFrame to display the first five rows and confirm that the changes are correct and as expected.
#
# Code demonstrates the practical ways of cleaning and exploring data first with type consistency, then the management of missing values, and finally, how to filter out irrelevant ones. It further reinforces iteration, such as verifying a glimpse of the modified dataset. While doing this exercise, I am reminded how important it is that documentation and reflection take priority so that this pre-processing step can be traceable and, importantly, easy to reproduce. Additional development would be related to the automation of repetitive tasks, introducing strong error handling, and incorporating categorical or textual data analysis. Overall, the code presents a considerate approach to EDA and sets up the best base for further analysis.

# %% [markdown]
# # Section 4: Data Visualization (16 marks)

# %% [markdown]
# # OBEJECTIVE:
#
# - The main aim of this section is to conduct advanced visual analysis to extract the trend, relationships, and distribution in the dataset of the NVIDIA stock. This is achieved by the following key tasks:
#
# - Correlation Heatmap:
#     - The "Close" price and "Volume" columns are visualized to understand the intensity and direction of their dependency.
#     - Judge the effect that "Volume" has on the "Close" price as an important factor to infer the trading pattern and the behavior of stocks.
#
# - Trend Analysis & Visualization:
#     - Map stock trends to number values for visualization of stock price trends.
# Do a scatter plot with an underlying line plot for closing price to depict the variation of the stock's trend with time.
# Add color bar for the trend mapping to ease the interpretation of the scatter plot.
#
# - Boxplots for Numerical Columns:
#     - Distribution, centrality, and outliers will be analyzed for all numerical columns in this dataset.
#     - This will enable the detection of potential data anomalies or extremities that may affect further analysis or modeling.
#     - Compare several numerical columns that study the variability.
#
# This section aims to put together a combined insight into understanding the historical performance, trends, and distribution characteristics of the stock by combining these visualizations. These analyses may allow deriving further insights for decision-making purposes, such as determining investment strategies or other predictive models. It also underlines the importance of clear and effective data visualization in presenting one's findings to a diverse range of audiences.

# %%
# Plotting Correlation heatmap for closing price and Volume

correlation_close(NVDA_df)

# %%
# Scatter plot for plotting trends
import matplotlib.dates as mdates

# Mapping Trend to Numerical values:
trend_map = {'Up':1, 'Down':-1, 'Flat':0}
NVDA_df['TrendValue'] = NVDA_df['Trend'].map(trend_map)

# Plotting
plt.style.use('seaborn-v0_8-darkgrid')
fix, ax = plt.subplots(figsize=(12, 6))

# Plotting Close Prize Line:
ax.plot(NVDA_df['Date'], NVDA_df['Close'], label='Close Price', color='blue', alpha=0.8)

#Plotting Trend Scatter
scatter = ax.scatter(NVDA_df['Date'], NVDA_df['Close'],
                     c=NVDA_df['TrendValue'], cmap='RdYlGn',
                     label="Trend", s=10, alpha=0.6)

# Adding Color Bar:
cbar = plt.colorbar(scatter, ax=ax)
cbar.set_label('Trend (1: Up, -1: Down, 0: Flat)')

# Formatting X-axis for showing dates:
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=6))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.xticks(rotation=45) #Rotation for better readibility

plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('NVDA Stock Market Trends')
plt.legend()
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Box ploting of numerical Columns:

for cols in num_cols:

    sns.boxplot(NVDA_df[cols])
    plt.title(f"Box-Plot for {cols}")
    plt.show()

# %% [markdown]
# # Reflection:
#
# - Strengths:
#     - The overall design of the visualization is attractive and conveys the key messages with ease.
#     - Many visualization techniques are presented, which would allow satisfying many analytic needs, starting with the relationship analysis, identification of a trend, to more detailed assessment of the distributions.
#
# - Limitations:
#     - The information given to the visualization could be richer if somehow linked with some description or even annotated-exampled on the scatterplot by key events.
#     - More informative boxplots, possibly labels of axes, will also provide choices to customize in order to develop a better design.
#
# - Learning Outcomes:
#     - I really enjoyed this part-how important it is synthesizing statistical knowledge with visual insight while presenting the finding efficiently.
#     - Greatly benefited by deep diving into how to present well-visualizing visualizations via Python libraries Matplotlib, Seaborn, Pandas.
#     - It increased my awareness of investing time in making careful formatting and nitty-gritties that actually make a visualization more accessible and potent.
#
# Overall, This section fills in the gap between raw data and actionable insights through good visualization techniques. Besides, it captures and highlights how effective visuals can be in representing hidden patterns and trends without actually being an indispensable component of the data analytics process.

# %% [markdown]
# # Section 5: GUI Development (16 marks)

# %% [markdown]
# # OBJECTIVE:
#
# - This section will design and implement an interactive GUI-based visualization for depicting the dynamic trends of NVIDIA stock prices. For this purpose, Tkinter is going to be used for GUI, while Matplotlib is to be used for the visualization of the data. This GUI application will be capable of plotting "Close Price" for NVIDIA stocks. Hence, showing trends-up, down, flat-using color-coded markers so as to enable the user to pinpoint the variations within the stock in a single glance. Such a one-page GUI visual, in addition, supports users of all categories-be they beginners or advanced-to take part in interactivity with the data and visualize it without the need to write code.
#
# - Given the general aim of this section, it would appear to be an attempt to bridge the wide gap that seems to exist between the technical analysis of data and its practical usability by making available easy access to an interface presenting complicated data in easily understandable forms. This pictorial representation of trends empowers the user towards an understanding of the nature of stocks, thus helping in tracing key patterns in stock performance.
#
# - Second, this section depicts the power of Python in stitching together the utilities of different libraries to provide an integrated solution. It again attests to event-driven programming for being able to deal with such an interface in real time, showing how GUI-based tools help to make data-driven insight more accessible and useful. This is quite an efficient methodology, since financial, data science, and business analytics analysts study stock trends and communicate them efficiently.

# %%
# Importing required libraries
import tkinter as tk  #Tkinter for GUI creation
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg  #For embedding Matplotlib plots in Tkinter
import matplotlib.pyplot as plt  #For creating plots

#Function to plot the NVDA stock price trend
def plot_trend():
    '''
    This function will create a Matplotlib plot of the 'Close Price' of the NVDA stock against time and color-codes, with colored markers, the trend of each data point-Up, Down, Flat:
    The plot is shown in the Tkinter GUI window.
    '''
    #Creating a Matplotlib figure and axis
    fig, ax = plt.subplots(figsize=(8, 6))
    
    #Plotting the 'Close Price' line
    ax.plot(NVDA_df['Date'], NVDA_df['Close'], label="Close Price", color='blue', alpha=0.7)
    
    #Highlight the trend (Up, Down, Flat)
    for i in range(1, len(NVDA_df)):
        if NVDA_df['Trend'].iloc[i] == "Up":
            ax.plot(NVDA_df['Date'].iloc[i], NVDA_df['Close'].iloc[i], 'go', label='Up Trend' if i == 1 else "")
        elif NVDA_df['Trend'].iloc[i] == "Down":
            ax.plot(NVDA_df['Date'].iloc[i], NVDA_df['Close'].iloc[i], 'ro', label='Down Trend' if i == 1 else "")
        else:
            ax.plot(NVDA_df['Date'].iloc[i], NVDA_df['Close'].iloc[i], 'yo', label='Flat Trend' if i == 1 else "")

    #Setting axis labels and title
    ax.set_xlabel('Date')
    ax.set_ylabel('Close Price')
    ax.set_title('NVDA Stock Price Trend')
    ax.legend()   #Adding a legend for the trend markers

    #Embedding the plot into the Tkinter window
    canvas = FigureCanvasTkAgg(fig, master=window)
    canvas.draw()
    canvas.get_tk_widget().pack()

#Creating the Tkinter main window
window = tk.Tk()
window.title("NVDA Stock Trend Viewer")   #Setting the title of the window

#Adding a button to trigger the trend plot
plot_button = tk.Button(window, text="Plot Trend", command=plot_trend)
plot_button.pack(pady=10)   #Adding some padding for better layout

#Running the loop
window.mainloop()
# Out:
# 2025-01-14 15:14:11.467 python[6880:2863196] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-01-14 15:14:11.467 python[6880:2863196] +[IMKInputSession subclass]: chose IMKInputSession_Modern

# %% [markdown]
# # Reflection:
#
# - This section combines data visualization with interactive GUI programming and is therefore even more interesting when analyzing the trends of NVIDIA stock. Python's flexibility in marrying data science with the building of user-friendly interfaces is demonstrated by using Tkinter to build a free-standing GUI application.
#
# - Reason:
#     - The main reason was to build an interactive application where users can look at stock price trends interactively.
#     - Using Matplotlib for the plotting and embedding the chart in a Tkinter window creates a seamless integration of GUI and data visualization.
#
# - Strengths and Achievements:
#     - The GUI is successful in presenting stock trend analysis to non-technical users who cannot understand how to code.
#     - Color-coded trend markers-green for "Up," red for "Down," yellow for "Flat"-provide clarity in visualizing the stock performance over time.
#     - Implementation is modular, the logic of plotting is wrapped inside a function (plot_trend), which makes the code easy to extend or modify.
#
# - Challenges and Limitations:
#     - This application presents all data in the dataset without filtering options. The addition of features, such as the selection of date ranges or trend-specific filtering, would enhance usability.
#     - The GUI design is very minimalistic; a lot more styling and adjustment could be done to make it look and feel professional.
#
# - Learning Outcomes:
#     - This exercise really drove home the combination of a number of Python libraries, notably Tkinter and Matplotlib, as one way to develop interactive applications.
#     - I had a good opportunity to internalize event-driven programming and how to embed visualizations into GUIs.
#     - The importance of user-centered design became clear through careful planning and testing involved in the creation of an intuitive interface.
#
# - Wider Applications:
#     - The GUI developed here has the potential to be a model for other datasets and applications, such as financial analysis, forecasting, or teaching.
#     - It fills in the huge gap between technical analysis and the accessibility of insights from data by the user through better actionability and comprehension.

# %% [markdown]
# # Section 6: Conclusion: Version Control, Critical Appraisal, Documentation (20 marks)

# %% [markdown]
# # CONCLUSION
#
# # SECTION-1:
# - Section 1 outlines the preliminary exploration and basic analysis of the NVIDIA dataset that will be extended further in later sections. The goals were to get an overview of its structure, identify key components, and provide an interactive way for a user to filter data in the dataset based on inputted dates.
#
# - The code first printed out the number of rows versus the number of columns in the dataset, thus giving an approximation of the general size and scope of the dataset. This step forms a basis for, or sets the stage in, understanding what one is working with.
#
# - Two lists were created to categorize the dataset columns into numerical and object types. Classifications into numerical and object-type columns are quintessential in determining the kinds of statistical or analytical techniques one can apply to these types of columns.
#
# - It is user driven—meaning that the functionality will filter this dataset based on the dates one has keyed in. The code checks the validity of the entered date format: YYYY-MM-DD and also searches the dataset for corresponding entries. In cases where there were no available data found on that particular date which was entered, a message informs the user. It makes not only interactivity better but really handy when narrowing down analysis to a very specific time frame of the dataset in question.
#
# - Code is well-structured and self-explanatory with each module performing its own function.
# Date input validation adds a lot of robustness and minimizes errors.
# Column categorization into numerical and object types offers a great base for deeper targeted analysis.
#
# - Error handling: The provided functionality can go a step ahead in offering hints on valid date ranges or simply correct minor mistakes made by a user in inputs like "2023-1-1" instead of "2023-01-01".
# - Scalability: There is room for improvement in this column categorization, so the same set of functions will scale better to many other datasets having diverse data types.
# Documentation: Better comments would make things clear to those using this; it's quite useful for example inputs and showing expected output formats.
# Section-1 is successful in setting up further data analysis by first ensuring clarity about the dataset being dealt with and allowing interactive filtering. Insights from here prove instrumental in steering the focus of further analyses. This section could be even more robust and user-friendly if it had additional improvements in error handling and scalability, along with enhanced documentation.
#
# #
#
# # SECTION-2
#
# - This section will dive deeper into extracting more insights from the NVIDIA dataset by computing some key metrics and detecting several trends. This is the next step in an in-depth exploration of the structure that starts extracting meaningful information which will aid in further interpretation and visualization of the data.
#
# - The following function returns the average of the column "Volume" in the dataset. The code loops over the column, updating the mean on the fly to summarize the data. This is an important step in terms of trading activity across the time frame of the dataset.
#
# - The following function will be utilized to capture the different trends of the column "Close" of the dataset. It computes the difference between consecutive values and labels them as "Up," "Down," or "Flat." This shall be important to understand the movement of the stock price and set up further ground either for visualizations or other statistical tests.
#
# - A further function defined is plotting the correlation heatmap between "Close" price vs. "Volume." It turns out to be pretty instrumental toward finding out the relationships between key variables which shall be helpful in finding some pattern or dependencies of the dataset.
# Strengths:
#
# - Modularized functionality - this makes them reusable over any similar datasets. The trend identification logic is pretty simple to understand and encompasses the price movements in a pretty simple yet meaningful way. The use of heat maps for the correlation analysis is intuitive since it is an easy way to visualize the relationships among different variables. Areas for Improvement:
#
# - Efficiency: Computation of the mean in 'calc_mean' with a list (l) is inefficient, and should be directly made through panda functions, which are faster and shorter. Error handling: Functions do not handle potential errors caused by missing or malformed input data. Adding this will make them much more robust. Visual integration: Heatmap function may have extra custom options, for example, dynamically selecting parameters, making it even more versatile.
#
# - Section 2 goes a step beyond what was initially laid down in Section 1 by introducing functions that enable the reader to make key calculations and analyze trends, thereby delivering some very interesting insights into stock behavior and thus variable relationships. This section does what it needs to but with greater emphasis on efficiency, error handling, and visualization flexibility—it would have greater analytical value. This section really shows how basic data exploration advances to actionable insights, a critical precursor to all data-driven decision-making.
#
# # SECTION-3
#
# - Section-3 revolves around cleaning and checking data quality so that the given dataset of NVIDIA is in a pure, consistent, and readily analyzable format. This section has laid much emphasis on handling data types of variables, missing and null values, and restructuring, so the data becomes good to read.
#
# - The .info() method was used on the dataset, and this included the count of data types of columns, non-null counts, and memory usage. This will help detect possible errors like data type issues or missing values within the records.
#
# - Changed the "Date" column from object type to datetime using pandas. The transformation of date columns to datetime format will definitely enable performing time-related operations in Python and other platforms with accuracy.
#
# - .isna().sum() was used in order to check for missing values in every column. This is very important because, once complete data is obtained, one might opt to impute it further or clean it.
#
# - .describe() was used for numeric columns for computing a summary of statistics: count, mean, max, min, standard deviation. Fast and rapid view of the distribution and variability within each column.
#
# - The "Adj Close" column was dropped as that would not be necessary for the analysis. Actually, this step justifies the importance of staying with only those features that are relevant for a speedy analysis.
#
# - Numerical columns are classified into a new list, discarding all irrelevant columns like "TrendValue." It keeps the dataset organized for further analysis.
#
# - The function.head() is called to show the first five lines of the new dataset to have a glance at what the current dataset looks like once it has been preprocessed.
#
# - This manipulation of data uses inbuilt pandas methods; hence, it is efficient and easy to analyze.
# The data type of the "Date" column has now been resolved, which makes it much easier to analyze for time-series.
# Irrelevant columns reduce noisiness, allowing only focused time-series features to be analyzed. Areas for Improvement:
#
# - Missing Value Handling: The code shows missing values; however, it fails to indicate how those are to be handled—imputation or removal—which will enhance the quality of the data.
# Dynamic Column Identification: The code could be more resilient if there were automation in identifying irrelevant columns. It can be dynamic for any other data as well.
# Documentation: Giving proper comments on each data preprocessing will help understand the reasoning behind every step.
#
# - Section 3 covers preprocessing-a necessary step of the pipeline in the data analysis chain. It lays a very good groundwork in ensuring the dataset is clean and organized, hence easy for efficient and correct analyses that may follow. Although it has met the expectations, the enhancement on missing values and automation can make the section more effective. At this stage, the reason behind data preparation becomes relevant for getting reliable results in analytical procedures.
#
# # SECTION-4
#
# - Section-4: The section remains committed to exploring key trends and relationships in the provided NVIDIA dataset through summary visualization. The section now moves from the preparation of data into EDA, thereby applying visualization to provide meaning into the movements of the stock price, volume of trade, and their respective relationships.
#
# - A correlation heatmap was drawn showing a relationship between the "Close" price and "Volume." This plot indicates the magnitude and direction of the relationship between the two variables, helping the analyst to identify any dependencies or patterns that could exist.
#
# - A scatter plot was drawn showing the trend of the stock's price over time. This plot uses color-coded markers-green, red, and yellow-accounting for upward, downward, and flat trends, respectively, and provides a clear intuitive sense of the way these prices have moved.
#
# - The "Trend" column has been mapped to numerical values (1 for "Up," -1 for "Down," and 0 for "Flat") to make this column visual in the scatter plot. This mapping strengthens the readability of the trends and therefore makes the plot more informative.
#
# - Box plots were done for the numerical columns to visualize their distribution and reveal any potential outliers. This forms another level of understanding in the grasp of the dataset through summarizing its statistical properties.
#
# - The visualizations are intuitive and bring forth the main insight.
# - Combination of scatter and line plots improves clarity around time series of the stock price.
# - Color coding about trends describes the stock performance instantly.
# - Box plots come in handy; they are simple to detect a few outliers and the nature of the distribution of data.
#
# - Context of Heatmap: An annotation or insight into the heatmap—for example, reading of the correlation coefficient—will help to give more meaning or make the visualization actionable.
# - Automating Dynamic Trend Mapping: This will highly reduce workload and increase its applicability.
# - Interactivity: Incorporation of interactive visualizations—using Plotly—will highly engage the user in an interactive exploration of data.
#
# - Section-4 does a great job of using various visualization methods to identify patterns and trends within the AMD or NVIDIA dataset the correlation heat maps, scatter plots, and box plots are combined in an effective way to get a good representation of relationships and distributions in the dataset. While the resulting visualizations are effective, drawing interpretive conclusions and incorporating interaction will add more value. Visualization has the potential to turn raw data into insight, connecting the chasm between analytics and decision-making.
#
# # SECTION-5
#
# - Section 5: The realization of data visualization in the GUI with the help of Tkinter in Python. It bridges the gap between the static analysis and active user interaction by offering a dynamic nature platform for the exploration of stock trends of NVIDIA.
#
# - GUI Creation through Tkinter:
# A very simple but effective GUI was created where the user could interact with the dataset.
# The GUI has a button "Plot Trend," on which the application plots the stock price trends.
#
# - Dynamic Visualization of Trend:
# plot_trend() generates a line plot of "Close" prices per time accompanied by color markers for upward, downward, and flat trends.
# The trend values are highlighted using different colors-green represents "Up," red represents "Down," and yellow represents "Flat"-on the plot for better intuition and user-friendliness.
# It carries an included color bar that depicts further information on the trend values.
# Event-Driven Programming:
#
# - Application GUI is dynamic it responds dynamically according to whatever event occurs on the GUI-by clicking the "Plot Trend" button in this application.
# This methodology increases the interactivity of the analysis and makes it accessible to a non-technical person.
# Matplotlib Integration:
#
# - The use of FigureCanvasTkAgg of Matplotlib embeds the visualization successfully within the Tkinter window.
# - This binder demonstrates how Python's libraries make it painless to combine data analyses and GUI development.
#
# - User-Friendliness: The interactive GUI makes it easy to access and view the analysis for users with little to no experience in coding.
# - Visualization Clarity: Well color-coded trends and labeled axes ensure ease of interpretation.
# - Reusability: The way in which the plot_trend function is modularly designed allows its application to different datasets or visualizations.
#
# - Interactivity: The GUI would be even more useful if users had options to select date ranges, custom visualizations, or filtering.
# - Error Handling: A more robust tool can be built by implementing error handling for expected problems—like missing data or incorrect column names.
# - Styling: Adding extra styling elements or even themes to the GUI would make it much more beautiful to look at.
#
# - This successfully combines data visualization with a user-friendly GUI, making the analysis of NVIDIA stock trends more interactive and accessible. This integration of Tkinter and Matplotlib demonstrates the versatility of Python in creating dynamic applications that cater to diverse user needs. While the current implementation is functional, adding more interactivity and customization options could further enhance its value. This section highlights the potential of interactive tools in democratizing data analysis and fostering a deeper understanding of complex datasets.
#
# # CRITICAL APPRAISAL
#
# Strengths:
# - Leveraging of Libraries: Tkinter has been used to create an interactive GUI, and matplotlib has been integrated into it seamlessly to visualize data. This is a good understanding of the matplotlib and Tkinter libraries.
#
# - Clear Visualization: The plot very clearly depicts the trend in the stock price with color-coded markers-green, red, and yellow for "Up," "Down," and "Flat" trends-making interpretation of the data by the user through visualization very effective.
#
# - Modular Design: The plotting logic has been encapsulated inside one function, plot_trend. This makes the code a lot cleaner and easier to maintain or extend.
#
# - User Interaction: It offers an interactive opportunity for the user through the "Plot Trend" button.
#
# - Customizable: It allows room for further customization of the plot using matplotlib-for example, grid lines, styles, etc.
#
# Weaknesses:
# - Reliance on External Data: The script assumes that a DataFrame named NVDA_df is available along with two columns, 'Date' and 'Close' and 'Trend.' However, within the project, it does not have any mechanism to either load or validate this data. Hence, it is not very robust as a standalone application.
#
# - Limited Error Handling:
# This code does not handle possible errors such as inability of finding certain data, spelling mistake in column names, or data type mismatch in the DataFrame; instead, it'll just crash if it catches an error.
#
# - Static Plot:
# The plot is static because the generation has been performed. Adding interactive visualization, like zooming, panning, or even tooltips showing, can make it much more usable.
#
# - GUI Design:
# The GUI is very basic and the following can easily be added to improve the design:
# Dropdown menus for choosing stocks or time frame.
# File upload options for the users to input their own data.
#
# - Scalability:
# This script currently is focused on one stock, NVDA. Of course, this can easily scale by modifying the script for several stocks, extending it to enable users to compare among themselves. Improvement Opportunities:
#
# Opportunity for Improvement:
#
# - Data Integration
# Adding integration with loading data from CSV or API, such as Yahoo Finance or Alpha Vantage will make the project much more dynamic and user-friendly.
#
# - Enhanced Trend Analysis
# Add trend analysis measures or visualizations, including but not limited to moving averages, Bollinger Bands, or candlestick charts to go deeper in analysis
#
# - User Interface Enhancements
# Enhance the GUI layout by using frames, labels, and dropdowns to give a nice look.
# Let the user customize plots by selecting date ranges or trend markers.
#
# - Interactive Plot
# By using plotly or mplcursors, the plot can easily be made interactive by allowing the user to hover over the points and present detailed information.
#
# - Documentation:
# Include full user instructions on how to prepare input data, run the script, and interpret the visualization.
#
# # VERSION CONTROL
#
# DAY-1
# - Summarizing the dataset and also trying to explain the background of the company to better connect with dataset.
# - Adding dataset from kaggle to work on the project.
# - Setting up github to my project to work on project.
#
# DAY-2
# - Importing all the necessary libraries.
# - Also working on the dataset by reading the dataset and trying to calulate the number of rows and column to know the total size of the data that i was working on.
# - Defining a function to calculate mean of volume & also calling meanVolume function.
#
# DAY-3
# - Defining the function to calulate the trend of the dataset closing stock price .
# - Making a function for plotting a correlation heatmap.
#
# DAY-4
# - Working on the section-4 with visualization the Plotting Correlation heatmap for closing price and Volume.
#
# DAY-5
# - Working with Scatter plot for plotting trends for visualizating the dataset.
# - Trying to make the code work by fixing the code to plot the stock market trend.
#
# DAY-6
# - Working on the research work for the code to perform as a lot of visualization work was not understood so a lot of learning process with in the day-6.
# - Also working on the reference and research working.
#
# DAY-7
# - Working on date column is wrongly typecasted as object let's convert it to datetime format.
# - Checking the dataset for dataFrame
# - And also checking the d.types to check the data type of the dataset that i was working on.
#
# Day-8
# - Working with .describe().
# - Checking for mean, max for the dataframe.
# - Box ploting for numerical column.
#
# DAY-9
# - Working on the GUI Development area,
# - Doing the research for the GUI revising the GUI with python part and trying to resolve the error in code.
#
# DAY-10
# - Working in GUI section.
# - Adding comments for each section of the project/
#
# DAY-11
# - Making the project appearance much better and adding the github token so the project dataset is fetched from the github repositry and not from the personal computer storage.
# - Improving the comments throughout the project and also solving the issues faced code in the process of adding and changes.
#
# DAY-12
# - Working on the Explaination, Documentation & Reflection part for section-1
# - Doing research work and commenting for section-2 Explaination, Documentation & Reflection.
#
# DAY-13
# - Working on the reflection for section-2.
# - Working on Explaination, Documentation & Reflection part for section-3 & section-4.
# - Working on the section-6 conclusion.
#
# DAY-14
# - Working on the reflection part of section-5.
# - Working on section-6 of explainting each section conclusion and also working on Version control

# %% [markdown]
# # References:

# %% [markdown]
# - NVIDIA Stock Data 1999 - 2024. LINK : https://www.kaggle.com/datasets/umerhaddii/nvidia-stock-data-2024. [Accessed on: 13 December]
# - Pandas 2024 . LINK : https://pandas.pydata.org/docs/getting_started/index.html. [Accessed on: 14 December]
# - NumPy 2024. LINK : https://numpy.org/doc/2.2/user/absolute_beginners.html. [Accessed on: 16 December]
# - Matplotlib 2024. LINK : https://matplotlib.org/stable/users/index.html. [Accessed on: 16 December]
# - Seaborn 2024. LINK : https://seaborn.pydata.org/index.html. [Accessed on: 20 December]
# - Tkinter 2024. LINK : https://docs.python.org/3/library/tkinter.html#. [Accessed on: 20 December]
